# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from unity_environment_wrapper import unity_env
env = unity_env(file_name="Reacher_Windows_x86_64/Reacher.exe", no_graphics=True, verbose_level=2)
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,
# Selected brain name:  ReacherBrain
# Selected brain:       Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
# ...

# %%
from DDPG_agent import DDPG_Agent
agent = DDPG_Agent(state_size = env.state_size, action_size = env.action_size, noise_sigma=1.0, use_cuda=True)
env.train(agent,"results")
# Out:
# Initializing DDPG_Agent with PyTorch device named: cuda:0
# Episode    1 score= 1.44 noise:[level=1.0000 theta=0.1500 sigma=1.0000 max= 7.65] curr window= Composite= -inf Average= 1.44 Stdev=  inf
# Episode    2 score= 0.67 noise:[level=0.9955 theta=0.1535 sigma=0.9950 max= 7.54] curr window= Composite= 0.51 Average= 1.05 Stdev= 0.54
# Episode    3 score= 0.96 noise:[level=0.9909 theta=0.1569 sigma=0.9900 max= 6.52] curr window= Composite= 0.63 Average= 1.02 Stdev= 0.39
# Episode    4 score= 0.72 noise:[level=0.9865 theta=0.1603 sigma=0.9851 max= 6.98] curr window= Composite= 0.60 Average= 0.95 Stdev= 0.35
# Episode    5 score= 1.50 noise:[level=0.9820 theta=0.1637 sigma=0.9801 max= 6.32] curr window= Composite= 0.67 Average= 1.06 Stdev= 0.39
# Episode    6 score= 0.82 noise:[level=0.9776 theta=0.1671 sigma=0.9752 max= 6.49] curr window= Composite= 0.65 Average= 1.02 Stdev= 0.36
# ...

# %%
env.test_agent_on_many_episodes(agent)
